# %% [markdown]
# # FY27 WP 服务单生成工具（Jupyter 版）
# 将本 Notebook、两个 Python 文件、`templates` 文件夹、`FY27 WP服务单.xlsx` 和 `FY27 section list.xlsx` 放在同一文件夹，然后依次运行下面两个单元格。

# %%
from pathlib import Path

WORK_FOLDER = Path.cwd()
print(f"当前工作文件夹：{WORK_FOLDER}")

# %%
from FY27_WP服务单生成工具 import run_generation

result = run_generation(WORK_FOLDER)
print(f"生成完成：{WORK_FOLDER / 'FY27+WP服务单汇总.xlsx'}")
print(
    f"服务方案 {result['services']} 张；"
    f"AUD2026 {result['aud2026_rows']} 个；"
    f"IPO {result['ipo_rows']} 个；"
    f"IPO archive {result['ipo_archive_rows']} 个。"
)
